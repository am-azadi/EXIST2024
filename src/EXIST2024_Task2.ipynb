# %%
# !pip install accelerate
# Out:
# Collecting accelerate
#   Downloading accelerate-0.30.0-py3-none-any.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 5.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from accelerate) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (24.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from accelerate) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from accelerate) (2.2.1+cu121)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.20.3)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.19.3 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nccl_cu12-2.19.3-py3-none-manylinux1_x86_64.whl (166.0 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.10.0->accelerate)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.2.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.10.0->accelerate) (2.2.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.10.0->accelerate)
#   Using cached nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (2.31.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->accelerate) (4.66.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->accelerate) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, accelerate
# Successfully installed accelerate-0.30.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.19.3 nvidia-nvjitlink-cu12-12.4.127 nvidia-nvtx-cu12-12.1.105

# %%
# %cd /content/drive/MyDrive/University/Research/EXIST 2024
# Out:
# /content/drive/MyDrive/University/Research/EXIST 2024

# %%
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, Dataset
from transformers import pipeline, XLMRobertaTokenizer, XLMRobertaForSequenceClassification, AutoTokenizer, AutoModelForSequenceClassification, get_linear_schedule_with_warmup
from sklearn.metrics import classification_report
from tqdm import tqdm
import numpy as np
import random

# %%
GLOBAL_SEED = 255

np.random.seed(GLOBAL_SEED)
random.seed(GLOBAL_SEED)
torch.manual_seed(GLOBAL_SEED)
torch.use_deterministic_algorithms(True)
# %env CUBLAS_WORKSPACE_CONFIG=:4096:8

torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False
# Out:
# env: CUBLAS_WORKSPACE_CONFIG=:4096:8

# %%
train_df = pd.read_json('./Data/EXIST 2024 Tweets Dataset/training/EXIST2024_training.json').transpose()
dev_df = pd.read_json('./Data/EXIST 2024 Tweets Dataset/dev/EXIST2024_dev.json').transpose()
test_df = pd.read_json('./Data/EXIST 2024 Tweets Dataset/test/EXIST2023_test_clean.json').transpose()

# %%
label2id = {'NO': 0, 'DIRECT': 1, 'REPORTED': 2, 'JUDGEMENTAL': 3}
id2label = {0: 'NO', 1: 'DIRECT', 2: 'REPORTED', 3: 'JUDGEMENTAL'}

def preprocess(df):
  if 'predicted_label' not in df.columns:
    df['predicted_label'] = df['labels_task2'].apply(lambda x: np.argmax([x.count('-'), x.count('DIRECT'), x.count('REPORTED'), x.count('JUDGEMENTAL')]))
  for column_name in ['number_annotators', 'annotators', 'gender_annotators', 'age_annotators', 'ethnicities_annotators', 'study_levels_annotators', 'countries_annotators', 'split']:
    if column_name in df.columns:
      df.drop(column_name, axis=1, inplace=True)
  return df

# %%
train_df = preprocess(train_df)
dev_df = preprocess(dev_df)

# %%
train_df
# Out:
#        id_EXIST lang                                              tweet  \
# 100001   100001   es  @TheChiflis Ignora al otro, es un capullo.El p...
# 100002   100002   es  @ultimonomada_ Si comicsgate se parece en algo...
# 100003   100003   es  @Steven2897 Lee sobre Gamergate, y como eso ha...
# 100004   100004   es  @Lunariita7 Un retraso social bastante lamenta...
# 100005   100005   es  @novadragon21 @icep4ck @TvDannyZ Entonces como...
# ...         ...  ...                                                ...
# 203256   203256   en  idk why y’all bitches think having half your a...
# 203257   203257   en  This has been a part of an experiment with @Wo...
# 203258   203258   en  "Take me already" "Not yet. You gotta be ready...
# 203259   203259   en  @clintneedcoffee why do you look like a whore?...
# 203260   203260   en  ik when mandy says “you look like a whore” i l...
#
#                           labels_task1  \
# 100001   [YES, YES, NO, YES, YES, YES]
# 100002       [NO, NO, NO, NO, YES, NO]
# 100003        [NO, NO, NO, NO, NO, NO]
# 100004     [NO, NO, YES, NO, YES, YES]
# 100005    [YES, NO, YES, NO, YES, YES]
# ...                                ...
# 203256  [YES, YES, YES, YES, YES, YES]
# 203257  [YES, YES, YES, YES, YES, YES]
# 203258    [NO, YES, NO, YES, YES, YES]
# 203259  [YES, YES, YES, YES, YES, YES]
# 203260   [YES, YES, YES, NO, YES, YES]
#
#                                              labels_task2  \
# 100001  [REPORTED, JUDGEMENTAL, -, REPORTED, JUDGEMENT...
# 100002                            [-, -, -, -, DIRECT, -]
# 100003                                 [-, -, -, -, -, -]
# 100004              [-, -, DIRECT, -, REPORTED, REPORTED]
# 100005  [REPORTED, -, JUDGEMENTAL, -, JUDGEMENTAL, DIR...
# ...                                                   ...
# 203256  [JUDGEMENTAL, DIRECT, DIRECT, DIRECT, JUDGEMEN...
# 203257  [JUDGEMENTAL, REPORTED, JUDGEMENTAL, DIRECT, J...
# 203258        [-, DIRECT, -, DIRECT, DIRECT, JUDGEMENTAL]
# 203259  [DIRECT, DIRECT, DIRECT, DIRECT, JUDGEMENTAL, ...
# 203260  [DIRECT, DIRECT, REPORTED, -, JUDGEMENTAL, REP...
#
#                                              labels_task3  predicted_label
# 100001  [[OBJECTIFICATION], [OBJECTIFICATION, SEXUAL-V...                2
# 100002       [[-], [-], [-], [-], [OBJECTIFICATION], [-]]                0
# 100003                     [[-], [-], [-], [-], [-], [-]]                0
# 100004  [[-], [-], [IDEOLOGICAL-INEQUALITY], [-], [IDE...                0
# 100005  [[STEREOTYPING-DOMINANCE, OBJECTIFICATION], [-...                0
# ...                                                   ...              ...
# 203256  [[OBJECTIFICATION], [STEREOTYPING-DOMINANCE, S...                1
# 203257  [[OBJECTIFICATION], [OBJECTIFICATION], [OBJECT...                3
# 203258  [[-], [OBJECTIFICATION], [-], [SEXUAL-VIOLENCE...                1
# 203259  [[OBJECTIFICATION, SEXUAL-VIOLENCE, MISOGYNY-N...                1
# 203260  [[STEREOTYPING-DOMINANCE], [OBJECTIFICATION], ...                1
#
# [6920 rows x 7 columns]

# %%
class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len=128):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            return_token_type_ids=False,
            padding='max_length',
            return_attention_mask=True,
            return_tensors='pt',
            truncation=True
        )
        return {
            'text': text,
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# %%
def load_model_and_tokenizer(model_name, number_of_labels):
  # Initialize tokenizer and model
  tokenizer = AutoTokenizer.from_pretrained(model_name)
  #model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels = number_of_labels, device_map = 'auto')
  model = AutoModelForSequenceClassification.from_pretrained(model_name, num_labels = number_of_labels)

  return model, tokenizer

def train_model(model, tokenizer, train_df, val_df, id2label, batch_size = 8, number_of_epochs = 3, learning_rates = [1e-5, 1e-5, 1e-5], weight_decay = 0.01):

  #save the best model based on accuracy on dev set
  best_model = model
  best_dev_loss = np.inf

  # Move the model to GPU
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  model.to(device)

  # Create datasets and dataloaders
  train_dataset = CustomDataset(train_df['tweet'].values, train_df['predicted_label'].values, tokenizer)
  val_dataset = CustomDataset(val_df['tweet'].values, val_df['predicted_label'].values, tokenizer)

  train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
  val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

  # Training loop (optional if you have labeled data)
  # Skip this part if you're doing zero-shot learning

  # Define early stopping
  best_val_loss = np.Inf
  patience = 3
  early_stopping_counter = 0

  # Train the model
  for epoch in range(number_of_epochs):
      # Define optimizer and loss function
      optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rates[epoch], weight_decay=weight_decay)
      total_steps = len(train_dataloader) * number_of_epochs
      scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=0, num_training_steps=total_steps)
      model.train()
      total_train_loss = 0
      total_train_correct = 0
      total_train_samples = 0

      for batch in tqdm(train_dataloader):
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        total_train_loss += loss.item()

        preds = torch.argmax(outputs.logits, dim=1)
        total_train_correct += (preds == labels).sum().item()
        total_train_samples += labels.shape[0]

        loss.backward()
        optimizer.step()
        scheduler.step()

      train_loss = total_train_loss / len(train_dataloader)
      train_acc = total_train_correct / total_train_samples


      # Evaluation for this epoch
      model.eval()
      val_losses = []
      total_dev_loss = 0
      total_dev_correct = 0
      total_dev_samples = 0

      for batch in tqdm(val_dataloader):
          input_ids = batch['input_ids'].to(device)
          attention_mask = batch['attention_mask'].to(device)
          labels = batch['labels'].to(device)

          with torch.no_grad():
              outputs = model(input_ids, attention_mask=attention_mask, labels=labels)
              val_losses.append(outputs.loss.item())

          loss = outputs.loss
          total_dev_loss += loss.item()

          preds = torch.argmax(outputs.logits, dim=1)
          total_dev_correct += (preds == labels).sum().item()
          total_dev_samples += labels.shape[0]

      avg_val_loss = np.mean(val_losses)

      dev_loss = total_dev_loss / len(val_dataloader)
      dev_acc = total_dev_correct / total_dev_samples

      if dev_loss < best_dev_loss:
        best_model = model
        best_dev_loss = dev_loss

      print(f'Epoch {epoch+1}/{number_of_epochs}')
      print(f'Train loss {train_loss}, accuracy {train_acc}')
      print(f'Dev loss {dev_loss}, accuracy {dev_acc}')

  # Load the best model
  return best_model, model, tokenizer

def Evaluate(model, tokenizer, val_df, id2label, batch_size = 8):

  # Move the model to GPU
  device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
  model.to(device)

  # Create datasets and dataloaders
  val_dataset = CustomDataset(val_df['tweet'].values, val_df['predicted_label'].values, tokenizer)

  val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

  # Evaluation
  model.eval()
  all_preds = []
  all_labels = []

  for batch in val_dataloader:
      input_ids = batch['input_ids'].to(device)
      attention_mask = batch['attention_mask'].to(device)
      labels = batch['labels'].to(device)

      with torch.no_grad():
          outputs = model(input_ids, attention_mask=attention_mask, labels=labels)

      logits = outputs.logits
      preds = torch.argmax(logits, dim=1).cpu().numpy()

      all_preds.extend(preds)
      all_labels.extend(labels.cpu().numpy())

  # Convert numerical labels back to text labels
  predicted_labels = [id2label[label] for label in all_preds]
  true_labels = [id2label[label] for label in all_labels]

  # Print classification report
  print(classification_report(true_labels, predicted_labels))
  return predicted_labels

# %%
from google.colab import userdata

def login2HF():
  # !huggingface-cli login --token '{userdata.get('HF_token')}'

# %%
login2HF()
# Out:
# Token will not been saved to git credential helper. Pass `add_to_git_credential=True` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
def save_and_upload(model, tokenizer, model_name2save):

  model.save_pretrained(model_name2save)
  tokenizer.save_pretrained(model_name2save)

# %% [markdown]
# ## RoBerta

# %%
roberta_large_model, roberta_large_tokenizer = load_model_and_tokenizer('xlm-roberta-large', 4)
best_roberta_large_model, roberta_large_model, roberta_large_tokenizer = train_model(roberta_large_model, roberta_large_tokenizer, train_df, dev_df, id2label, batch_size=16, number_of_epochs=3, learning_rates=[2e-5, 1e-5, 1e-5], weight_decay=0.03)
predicted_labels = Evaluate(best_roberta_large_model, roberta_large_tokenizer, dev_df, id2label, batch_size = 16)
# Out:
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-large and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 433/433 [08:47<00:00,  1.22s/it]
# 100%|██████████| 65/65 [00:23<00:00,  2.72it/s]
# Epoch 1/3
# Train loss 0.8651107886234002, accuracy 0.6708092485549133
# Dev loss 0.8275826793450576, accuracy 0.6714836223506744
# 100%|██████████| 433/433 [08:46<00:00,  1.22s/it]
# 100%|██████████| 65/65 [00:23<00:00,  2.72it/s]
# Epoch 2/3
# Train loss 0.686354171080347, accuracy 0.7263005780346821
# Dev loss 0.7184075181300823, accuracy 0.7061657032755299
# 100%|██████████| 433/433 [08:46<00:00,  1.22s/it]
# 100%|██████████| 65/65 [00:23<00:00,  2.71it/s]
# Epoch 3/3
# Train loss 0.598318569723508, accuracy 0.761849710982659
# Dev loss 0.747743614591085, accuracy 0.720616570327553
#               precision    recall  f1-score   support
#
#       DIRECT       0.62      0.57      0.59       230
#  JUDGEMENTAL       0.62      0.13      0.21        79
#           NO       0.80      0.89      0.84       646
#     REPORTED       0.35      0.37      0.36        83
#
#     accuracy                           0.72      1038
#    macro avg       0.60      0.49      0.50      1038
# weighted avg       0.71      0.72      0.70      1038

# %%
save_and_upload(roberta_large_model, roberta_large_tokenizer, 'EXIST2024_Task2_xlmRoberta_large_3_16')
# !huggingface-cli upload 'EXIST2024_Task2_xlmRoberta_large_3_16'
# Out:
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Upload 3 LFS files:   0% 0/3 [00:00<?, ?it/s]
# sentencepiece.bpe.model:   0% 0.00/5.07M [00:00<?, ?B/s]
#
# tokenizer.json:   0% 0.00/17.1M [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0% 16.4k/5.07M [00:00<01:12, 70.0kB/s]
#
# tokenizer.json:   0% 16.4k/17.1M [00:00<03:51, 73.6kB/s]
#
#
# model.safetensors:   0% 0.00/2.24G [00:00<?, ?B/s]
# sentencepiece.bpe.model:  29% 1.47M/5.07M [00:00<00:00, 5.28MB/s]
#
# tokenizer.json:   9% 1.52M/17.1M [00:00<00:02, 5.56MB/s]
# sentencepiece.bpe.model:  62% 3.16M/5.07M [00:00<00:00, 8.07MB/s]
#
# tokenizer.json:  16% 2.69M/17.1M [00:00<00:02, 6.40MB/s]
#
#
# model.safetensors:   0% 16.4k/2.24G [00:00<6:59:31, 89.0kB/s]
#
#
# model.safetensors:   0% 999k/2.24G [00:00<08:47, 4.25MB/s]
#
# tokenizer.json:  29% 4.95M/17.1M [00:00<00:01, 10.0MB/s]
#
#
# model.safetensors:   0% 2.56M/2.24G [00:00<04:47, 7.79MB/s]
#
# sentencepiece.bpe.model: 100% 5.07M/5.07M [00:00<00:00, 6.18MB/s]
#
#
# tokenizer.json:  82% 13.9M/17.1M [00:00<00:00, 26.4MB/s]
#
#
# model.safetensors:   0% 4.42M/2.24G [00:00<03:35, 10.4MB/s]
#
#
# model.safetensors:   0% 5.85M/2.24G [00:00<03:31, 10.5MB/s]
#
#
# model.safetensors:   0% 8.63M/2.24G [00:00<02:30, 14.9MB/s]
#
# tokenizer.json:  99% 16.9M/17.1M [00:01<00:00, 16.7MB/s]
#
#
# model.safetensors:   1% 13.5M/2.24G [00:00<01:32, 24.0MB/s]
#
#
# tokenizer.json: 100% 17.1M/17.1M [00:01<00:00, 10.7MB/s]
#
#
#
# model.safetensors:   1% 23.1M/2.24G [00:01<01:24, 26.3MB/s]
#
#
# model.safetensors:   1% 26.6M/2.24G [00:01<01:18, 28.1MB/s]
#
#
# model.safetensors:   1% 32.0M/2.24G [00:01<01:26, 25.4MB/s]
#
#
# model.safetensors:   2% 38.9M/2.24G [00:01<01:08, 31.9MB/s]
#
#
# model.safetensors:   2% 42.7M/2.24G [00:01<01:07, 32.3MB/s]
#
#
# model.safetensors:   2% 46.3M/2.24G [00:02<01:08, 31.9MB/s]
#
#
# model.safetensors:   2% 49.8M/2.24G [00:02<01:38, 22.2MB/s]
#
#
# model.safetensors:   3% 62.0M/2.24G [00:02<00:55, 39.3MB/s]
#
#
# model.safetensors:   3% 66.9M/2.24G [00:02<01:05, 33.2MB/s]
#
#
# model.safetensors:   3% 71.3M/2.24G [00:02<01:03, 34.2MB/s]
#
#
# model.safetensors:   3% 75.3M/2.24G [00:02<01:08, 31.8MB/s]
#
#
# model.safetensors:   4% 78.9M/2.24G [00:03<01:07, 31.9MB/s]
#
#
# model.safetensors:   4% 82.4M/2.24G [00:03<01:41, 21.3MB/s]
#
#
# model.safetensors:   4% 88.8M/2.24G [00:03<01:22, 25.9MB/s]
#
#
# model.safetensors:   4% 91.9M/2.24G [00:03<01:25, 25.0MB/s]
#
#
# model.safetensors:   4% 96.0M/2.24G [00:04<01:56, 18.4MB/s]
#
#
# model.safetensors:   5% 106M/2.24G [00:04<01:11, 29.7MB/s]
#
#
# model.safetensors:   5% 110M/2.24G [00:04<01:23, 25.5MB/s]
#
#
# model.safetensors:   5% 113M/2.24G [00:04<01:52, 18.9MB/s]
#
#
# model.safetensors:   5% 121M/2.24G [00:04<01:17, 27.3MB/s]
#
#
# model.safetensors:   6% 128M/2.24G [00:05<01:19, 26.6MB/s]
#
#
# model.safetensors:   6% 138M/2.24G [00:05<00:54, 38.8MB/s]
#
#
# model.safetensors:   6% 144M/2.24G [00:05<01:04, 32.3MB/s]
#
#
# model.safetensors:   7% 154M/2.24G [00:05<00:47, 43.5MB/s]
#
#
# model.safetensors:   7% 160M/2.24G [00:05<00:56, 36.9MB/s]
#
#
# model.safetensors:   8% 170M/2.24G [00:05<00:44, 46.8MB/s]
#
#
# model.safetensors:   8% 176M/2.24G [00:06<01:05, 31.7MB/s]
#
#
# model.safetensors:   8% 185M/2.24G [00:06<00:50, 40.7MB/s]
#
#
# model.safetensors:   9% 192M/2.24G [00:06<01:07, 30.4MB/s]
#
#
# model.safetensors:   9% 199M/2.24G [00:06<00:57, 35.6MB/s]
#
#
# model.safetensors:   9% 205M/2.24G [00:07<00:58, 34.6MB/s]
#
#
# model.safetensors:   9% 209M/2.24G [00:07<01:23, 24.4MB/s]
#
#
# model.safetensors:  10% 217M/2.24G [00:07<01:03, 32.0MB/s]
#
#
# model.safetensors:  10% 224M/2.24G [00:07<01:14, 27.0MB/s]
#
#
# model.safetensors:  10% 234M/2.24G [00:08<00:54, 36.6MB/s]
#
#
# model.safetensors:  11% 240M/2.24G [00:08<01:08, 29.3MB/s]
#
#
# model.safetensors:  11% 250M/2.24G [00:08<00:52, 38.1MB/s]
#
#
# model.safetensors:  11% 256M/2.24G [00:08<01:09, 28.7MB/s]
#
#
# model.safetensors:  12% 265M/2.24G [00:09<00:53, 36.8MB/s]
#
#
# model.safetensors:  12% 272M/2.24G [00:09<00:57, 34.4MB/s]
#
#
# model.safetensors:  13% 282M/2.24G [00:09<00:44, 44.1MB/s]
#
#
# model.safetensors:  13% 288M/2.24G [00:09<00:55, 35.3MB/s]
#
#
# model.safetensors:  13% 299M/2.24G [00:09<00:42, 45.2MB/s]
#
#
# model.safetensors:  14% 305M/2.24G [00:09<00:49, 38.8MB/s]
#
#
# model.safetensors:  14% 314M/2.24G [00:10<00:39, 48.6MB/s]
#
#
# model.safetensors:  14% 320M/2.24G [00:10<00:55, 34.5MB/s]
#
#
# model.safetensors:  15% 330M/2.24G [00:10<00:44, 42.6MB/s]
#
#
# model.safetensors:  15% 336M/2.24G [00:10<00:52, 36.5MB/s]
#
#
# model.safetensors:  15% 346M/2.24G [00:10<00:41, 45.2MB/s]
#
#
# model.safetensors:  16% 352M/2.24G [00:11<00:55, 33.8MB/s]
#
#
# model.safetensors:  16% 364M/2.24G [00:11<00:40, 46.9MB/s]
#
#
# model.safetensors:  17% 371M/2.24G [00:11<00:46, 40.0MB/s]
#
#
# model.safetensors:  17% 382M/2.24G [00:11<00:36, 50.7MB/s]
#
#
# model.safetensors:  17% 388M/2.24G [00:11<00:45, 40.7MB/s]
#
#
# model.safetensors:  18% 396M/2.24G [00:12<00:41, 44.2MB/s]
#
#
# model.safetensors:  18% 401M/2.24G [00:12<00:49, 37.5MB/s]
#
#
# model.safetensors:  18% 410M/2.24G [00:12<00:39, 46.1MB/s]
#
#
# model.safetensors:  19% 416M/2.24G [00:12<00:47, 38.0MB/s]
#
#
# model.safetensors:  19% 428M/2.24G [00:12<00:33, 53.8MB/s]
#
#
# model.safetensors:  19% 436M/2.24G [00:12<00:38, 47.1MB/s]
#
#
# model.safetensors:  20% 444M/2.24G [00:13<00:34, 51.4MB/s]
#
#
# model.safetensors:  20% 450M/2.24G [00:14<01:34, 18.9MB/s]
#
#
# model.safetensors:  21% 460M/2.24G [00:14<01:07, 26.3MB/s]
#
#
# model.safetensors:  21% 466M/2.24G [00:14<01:08, 26.0MB/s]
#
#
# model.safetensors:  21% 475M/2.24G [00:14<00:51, 34.3MB/s]
#
#
# model.safetensors:  21% 481M/2.24G [00:14<00:53, 32.9MB/s]
#
#
# model.safetensors:  22% 492M/2.24G [00:14<00:38, 45.2MB/s]
#
#
# model.safetensors:  22% 499M/2.24G [00:15<00:45, 38.3MB/s]
#
#
# model.safetensors:  23% 506M/2.24G [00:15<00:39, 44.2MB/s]
#
#
# model.safetensors:  23% 512M/2.24G [00:15<00:47, 36.6MB/s]
#
#
# model.safetensors:  23% 521M/2.24G [00:15<00:38, 45.0MB/s]
#
#
# model.safetensors:  24% 528M/2.24G [00:15<00:55, 31.1MB/s]
#
#
# model.safetensors:  24% 541M/2.24G [00:16<00:38, 44.4MB/s]
#
#
# model.safetensors:  24% 548M/2.24G [00:16<00:53, 31.8MB/s]
#
#
# model.safetensors:  25% 554M/2.24G [00:16<00:46, 36.4MB/s]
#
#
# model.safetensors:  25% 560M/2.24G [00:16<00:57, 29.1MB/s]
#
#
# model.safetensors:  26% 573M/2.24G [00:17<00:39, 42.3MB/s]
#
#
# model.safetensors:  26% 579M/2.24G [00:17<00:45, 36.5MB/s]
#
#
# model.safetensors:  26% 586M/2.24G [00:17<00:39, 42.0MB/s]
#
#
# model.safetensors:  26% 592M/2.24G [00:17<00:46, 35.6MB/s]
#
#
# model.safetensors:  27% 601M/2.24G [00:17<00:36, 44.8MB/s]
#
#
# model.safetensors:  27% 608M/2.24G [00:18<00:45, 36.0MB/s]
#
#
# model.safetensors:  28% 618M/2.24G [00:18<00:35, 46.1MB/s]
#
#
# model.safetensors:  28% 624M/2.24G [00:18<00:48, 33.4MB/s]
#
#
# model.safetensors:  28% 634M/2.24G [00:18<00:38, 41.8MB/s]
#
#
# model.safetensors:  29% 640M/2.24G [00:18<00:49, 32.2MB/s]
#
#
# model.safetensors:  29% 651M/2.24G [00:19<00:37, 42.2MB/s]
#
#
# model.safetensors:  29% 657M/2.24G [00:19<00:43, 36.1MB/s]
#
#
# model.safetensors:  30% 668M/2.24G [00:19<00:32, 48.7MB/s]
#
#
# model.safetensors:  30% 675M/2.24G [00:19<00:40, 38.8MB/s]
#
#
# model.safetensors:  30% 682M/2.24G [00:19<00:35, 44.2MB/s]
#
#
# model.safetensors:  31% 688M/2.24G [00:20<00:47, 32.6MB/s]
#
#
# model.safetensors:  31% 697M/2.24G [00:20<00:36, 42.3MB/s]
#
#
# model.safetensors:  31% 704M/2.24G [00:20<00:42, 36.2MB/s]
#
#
# model.safetensors:  32% 715M/2.24G [00:20<00:31, 48.4MB/s]
#
#
# model.safetensors:  32% 722M/2.24G [00:20<00:37, 40.6MB/s]
#
#
# model.safetensors:  33% 732M/2.24G [00:20<00:29, 50.4MB/s]
#
#
# model.safetensors:  33% 739M/2.24G [00:21<00:36, 40.7MB/s]
#
#
# model.safetensors:  33% 746M/2.24G [00:21<00:32, 46.2MB/s]
#
#
# model.safetensors:  34% 752M/2.24G [00:21<00:46, 32.3MB/s]
#
#
# model.safetensors:  34% 762M/2.24G [00:21<00:35, 41.6MB/s]
#
#
# model.safetensors:  34% 768M/2.24G [00:22<00:39, 36.8MB/s]
#
#
# model.safetensors:  35% 778M/2.24G [00:22<00:31, 46.5MB/s]
#
#
# model.safetensors:  35% 784M/2.24G [00:22<00:41, 34.9MB/s]
#
#
# model.safetensors:  35% 794M/2.24G [00:22<00:32, 44.0MB/s]
#
#
# model.safetensors:  36% 800M/2.24G [00:22<00:40, 35.2MB/s]
#
#
# model.safetensors:  36% 813M/2.24G [00:22<00:28, 50.4MB/s]
#
#
# model.safetensors:  37% 820M/2.24G [00:23<00:32, 43.7MB/s]
#
#
# model.safetensors:  37% 830M/2.24G [00:23<00:27, 51.0MB/s]
#
#
# model.safetensors:  37% 836M/2.24G [00:23<00:33, 42.2MB/s]
#
#
# model.safetensors:  38% 848M/2.24G [00:23<00:25, 54.6MB/s]
#
#
# model.safetensors:  38% 855M/2.24G [00:23<00:31, 44.1MB/s]
#
#
# model.safetensors:  39% 864M/2.24G [00:24<00:38, 36.0MB/s]
#
#
# model.safetensors:  39% 879M/2.24G [00:24<00:25, 52.9MB/s]
#
#
# model.safetensors:  40% 887M/2.24G [00:24<00:30, 44.5MB/s]
#
#
# model.safetensors:  40% 896M/2.24G [00:24<00:35, 37.5MB/s]
#
#
# model.safetensors:  41% 910M/2.24G [00:25<00:25, 51.6MB/s]
#
#
# model.safetensors:  41% 917M/2.24G [00:25<00:27, 48.1MB/s]
#
#
# model.safetensors:  41% 928M/2.24G [00:25<00:30, 43.7MB/s]
#
#
# model.safetensors:  42% 942M/2.24G [00:25<00:22, 58.6MB/s]
#
#
# model.safetensors:  42% 950M/2.24G [00:25<00:27, 46.8MB/s]
#
#
# model.safetensors:  43% 960M/2.24G [00:26<00:30, 42.5MB/s]
#
#
# model.safetensors:  43% 974M/2.24G [00:26<00:22, 56.7MB/s]
#
#
# model.safetensors:  44% 982M/2.24G [00:26<00:25, 48.8MB/s]
#
#
# model.safetensors:  44% 992M/2.24G [00:26<00:27, 46.0MB/s]
#
#
# model.safetensors:  45% 1.01G/2.24G [00:26<00:20, 61.3MB/s]
#
#
# model.safetensors:  45% 1.01G/2.24G [00:27<00:23, 51.3MB/s]
#
#
# model.safetensors:  46% 1.02G/2.24G [00:27<00:27, 44.1MB/s]
#
#
# model.safetensors:  46% 1.04G/2.24G [00:27<00:20, 59.2MB/s]
#
#
# model.safetensors:  47% 1.05G/2.24G [00:27<00:21, 55.0MB/s]
#
#
# model.safetensors:  47% 1.06G/2.24G [00:28<00:29, 39.6MB/s]
#
#
# model.safetensors:  48% 1.07G/2.24G [00:28<00:21, 53.4MB/s]
#
#
# model.safetensors:  48% 1.08G/2.24G [00:28<00:26, 43.3MB/s]
#
#
# model.safetensors:  49% 1.09G/2.24G [00:28<00:27, 41.7MB/s]
#
#
# model.safetensors:  49% 1.10G/2.24G [00:28<00:20, 56.1MB/s]
#
#
# model.safetensors:  50% 1.11G/2.24G [00:29<00:21, 51.6MB/s]
#
#
# model.safetensors:  50% 1.12G/2.24G [00:29<00:25, 44.2MB/s]
#
#
# model.safetensors:  51% 1.13G/2.24G [00:29<00:18, 58.6MB/s]
#
#
# model.safetensors:  51% 1.14G/2.24G [00:29<00:21, 51.1MB/s]
#
#
# model.safetensors:  51% 1.15G/2.24G [00:30<00:27, 39.1MB/s]
#
#
# model.safetensors:  52% 1.17G/2.24G [00:30<00:20, 52.6MB/s]
#
#
# model.safetensors:  52% 1.17G/2.24G [00:30<00:23, 45.2MB/s]
#
#
# model.safetensors:  53% 1.18G/2.24G [00:30<00:25, 41.1MB/s]
#
#
# model.safetensors:  54% 1.20G/2.24G [00:30<00:18, 55.5MB/s]
#
#
# model.safetensors:  54% 1.21G/2.24G [00:31<00:22, 46.0MB/s]
#
#
# model.safetensors:  54% 1.22G/2.24G [00:31<00:23, 43.4MB/s]
#
#
# model.safetensors:  55% 1.23G/2.24G [00:31<00:17, 58.1MB/s]
#
#
# model.safetensors:  55% 1.24G/2.24G [00:31<00:19, 50.7MB/s]
#
#
# model.safetensors:  56% 1.25G/2.24G [00:32<00:21, 46.9MB/s]
#
#
# model.safetensors:  56% 1.26G/2.24G [00:32<00:15, 61.4MB/s]
#
#
# model.safetensors:  57% 1.27G/2.24G [00:32<00:18, 51.1MB/s]
#
#
# model.safetensors:  57% 1.28G/2.24G [00:32<00:20, 47.6MB/s]
#
#
# model.safetensors:  58% 1.29G/2.24G [00:32<00:14, 63.3MB/s]
#
#
# model.safetensors:  58% 1.30G/2.24G [00:32<00:17, 53.8MB/s]
#
#
# model.safetensors:  59% 1.31G/2.24G [00:33<00:21, 42.6MB/s]
#
#
# model.safetensors:  59% 1.33G/2.24G [00:33<00:15, 57.2MB/s]
#
#
# model.safetensors:  60% 1.33G/2.24G [00:33<00:19, 46.4MB/s]
#
#
# model.safetensors:  60% 1.34G/2.24G [00:33<00:20, 43.2MB/s]
#
#
# model.safetensors:  61% 1.36G/2.24G [00:34<00:15, 57.7MB/s]
#
#
# model.safetensors:  61% 1.37G/2.24G [00:34<00:17, 51.3MB/s]
#
#
# model.safetensors:  61% 1.38G/2.24G [00:34<00:21, 39.3MB/s]
#
#
# model.safetensors:  62% 1.39G/2.24G [00:34<00:15, 54.2MB/s]
#
#
# model.safetensors:  62% 1.40G/2.24G [00:35<00:19, 43.2MB/s]
#
#
# model.safetensors:  63% 1.41G/2.24G [00:35<00:23, 35.6MB/s]
#
#
# model.safetensors:  63% 1.42G/2.24G [00:35<00:16, 48.6MB/s]
#
#
# model.safetensors:  64% 1.43G/2.24G [00:35<00:22, 35.8MB/s]
#
#
# model.safetensors:  64% 1.44G/2.24G [00:36<00:21, 36.4MB/s]
#
#
# model.safetensors:  65% 1.45G/2.24G [00:36<00:15, 50.8MB/s]
#
#
# model.safetensors:  65% 1.46G/2.24G [00:36<00:17, 45.6MB/s]
#
#
# model.safetensors:  66% 1.47G/2.24G [00:36<00:18, 42.1MB/s]
#
#
# model.safetensors:  66% 1.49G/2.24G [00:36<00:13, 57.0MB/s]
#
#
# model.safetensors:  67% 1.49G/2.24G [00:37<00:16, 45.7MB/s]
#
#
# model.safetensors:  67% 1.50G/2.24G [00:37<00:18, 40.8MB/s]
#
#
# model.safetensors:  68% 1.52G/2.24G [00:37<00:12, 56.2MB/s]
#
#
# model.safetensors:  68% 1.53G/2.24G [00:37<00:15, 45.5MB/s]
#
#
# model.safetensors:  69% 1.54G/2.24G [00:38<00:15, 44.5MB/s]
#
#
# model.safetensors:  69% 1.55G/2.24G [00:38<00:11, 58.9MB/s]
#
#
# model.safetensors:  70% 1.56G/2.24G [00:38<00:14, 48.1MB/s]
#
#
# model.safetensors:  70% 1.57G/2.24G [00:38<00:15, 42.7MB/s]
#
#
# model.safetensors:  71% 1.58G/2.24G [00:38<00:11, 57.2MB/s]
#
#
# model.safetensors:  71% 1.59G/2.24G [00:39<00:13, 49.9MB/s]
#
#
# model.safetensors:  71% 1.60G/2.24G [00:39<00:15, 41.5MB/s]
#
#
# model.safetensors:  72% 1.61G/2.24G [00:39<00:11, 55.9MB/s]
#
#
# model.safetensors:  72% 1.62G/2.24G [00:39<00:12, 47.7MB/s]
#
#
# model.safetensors:  73% 1.63G/2.24G [00:40<00:15, 39.5MB/s]
#
#
# model.safetensors:  73% 1.65G/2.24G [00:40<00:11, 52.7MB/s]
#
#
# model.safetensors:  74% 1.65G/2.24G [00:40<00:13, 43.1MB/s]
#
#
# model.safetensors:  74% 1.66G/2.24G [00:41<00:17, 32.5MB/s]
#
#
# model.safetensors:  75% 1.68G/2.24G [00:41<00:12, 45.0MB/s]
#
#
# model.safetensors:  75% 1.69G/2.24G [00:41<00:13, 41.5MB/s]
#
#
# model.safetensors:  76% 1.70G/2.24G [00:41<00:13, 40.6MB/s]
#
#
# model.safetensors:  76% 1.71G/2.24G [00:41<00:09, 54.5MB/s]
#
#
# model.safetensors:  77% 1.72G/2.24G [00:42<00:10, 48.4MB/s]
#
#
# model.safetensors:  77% 1.73G/2.24G [00:42<00:11, 44.1MB/s]
#
#
# model.safetensors:  78% 1.74G/2.24G [00:42<00:08, 58.7MB/s]
#
#
# model.safetensors:  78% 1.75G/2.24G [00:42<00:09, 50.9MB/s]
#
#
# model.safetensors:  79% 1.76G/2.24G [00:42<00:10, 43.7MB/s]
#
#
# model.safetensors:  79% 1.77G/2.24G [00:43<00:07, 58.6MB/s]
#
#
# model.safetensors:  80% 1.78G/2.24G [00:43<00:08, 51.1MB/s]
#
#
# model.safetensors:  80% 1.79G/2.24G [00:43<00:10, 44.4MB/s]
#
#
# model.safetensors:  81% 1.81G/2.24G [00:43<00:07, 60.4MB/s]
#
#
# model.safetensors:  81% 1.81G/2.24G [00:43<00:08, 48.8MB/s]
#
#
# model.safetensors:  81% 1.82G/2.24G [00:44<00:09, 44.4MB/s]
#
#
# model.safetensors:  82% 1.84G/2.24G [00:44<00:06, 59.4MB/s]
#
#
# model.safetensors:  82% 1.85G/2.24G [00:44<00:07, 51.0MB/s]
#
#
# model.safetensors:  83% 1.86G/2.24G [00:44<00:09, 42.1MB/s]
#
#
# model.safetensors:  84% 1.87G/2.24G [00:45<00:06, 57.0MB/s]
#
#
# model.safetensors:  84% 1.88G/2.24G [00:45<00:07, 49.0MB/s]
#
#
# model.safetensors:  84% 1.89G/2.24G [00:45<00:08, 41.7MB/s]
#
#
# model.safetensors:  85% 1.90G/2.24G [00:45<00:06, 56.0MB/s]
#
#
# model.safetensors:  85% 1.91G/2.24G [00:45<00:07, 42.5MB/s]
#
#
# model.safetensors:  86% 1.92G/2.24G [00:46<00:08, 39.0MB/s]
#
#
# model.safetensors:  86% 1.93G/2.24G [00:46<00:05, 53.4MB/s]
#
#
# model.safetensors:  87% 1.94G/2.24G [00:46<00:06, 45.4MB/s]
#
#
# model.safetensors:  87% 1.95G/2.24G [00:46<00:06, 41.3MB/s]
#
#
# model.safetensors:  88% 1.97G/2.24G [00:47<00:04, 55.7MB/s]
#
#
# model.safetensors:  88% 1.97G/2.24G [00:47<00:05, 47.3MB/s]
#
#
# model.safetensors:  89% 1.98G/2.24G [00:47<00:05, 43.7MB/s]
#
#
# model.safetensors:  89% 2.00G/2.24G [00:47<00:04, 57.8MB/s]
#
#
# model.safetensors:  90% 2.01G/2.24G [00:48<00:05, 43.8MB/s]
#
#
# model.safetensors:  90% 2.02G/2.24G [00:48<00:05, 39.1MB/s]
#
#
# model.safetensors:  91% 2.03G/2.24G [00:48<00:03, 53.2MB/s]
#
#
# model.safetensors:  91% 2.04G/2.24G [00:48<00:04, 47.4MB/s]
#
#
# model.safetensors:  91% 2.05G/2.24G [00:53<00:32, 5.92MB/s]
#
#
# model.safetensors:  92% 2.06G/2.24G [00:54<00:22, 8.14MB/s]
#
#
# model.safetensors:  92% 2.06G/2.24G [00:54<00:18, 9.58MB/s]
#
#
# model.safetensors:  93% 2.08G/2.24G [00:54<00:10, 15.5MB/s]
#
#
# model.safetensors:  93% 2.09G/2.24G [00:54<00:08, 17.9MB/s]
#
#
# model.safetensors:  94% 2.10G/2.24G [00:54<00:07, 20.0MB/s]
#
#
# model.safetensors:  94% 2.11G/2.24G [00:55<00:04, 29.3MB/s]
#
#
# model.safetensors:  95% 2.12G/2.24G [00:55<00:04, 30.1MB/s]
#
#
# model.safetensors:  95% 2.13G/2.24G [00:55<00:03, 30.3MB/s]
#
#
# model.safetensors:  96% 2.14G/2.24G [00:55<00:02, 42.7MB/s]
#
#
# model.safetensors:  96% 2.15G/2.24G [00:56<00:02, 37.9MB/s]
#
#
# model.safetensors:  96% 2.16G/2.24G [00:56<00:02, 36.2MB/s]
#
#
# model.safetensors:  97% 2.17G/2.24G [00:56<00:01, 50.2MB/s]
#
#
# model.safetensors:  97% 2.18G/2.24G [00:56<00:01, 46.0MB/s]
#
#
# model.safetensors:  98% 2.19G/2.24G [00:56<00:01, 40.4MB/s]
#
#
# model.safetensors:  98% 2.21G/2.24G [00:57<00:00, 54.4MB/s]
#
#
# model.safetensors:  99% 2.21G/2.24G [00:57<00:00, 43.6MB/s]
#
#
# model.safetensors:  99% 2.22G/2.24G [00:57<00:00, 41.7MB/s]
#
#
# model.safetensors: 100% 2.24G/2.24G [00:57<00:00, 38.7MB/s]
# Upload 3 LFS files: 100% 3/3 [00:58<00:00, 19.53s/it]
# https://huggingface.co/am-azadi/EXIST2024_Task2_xlmRoberta_large_3_16/tree/main/.

# %%
roberta_large_model, roberta_large_tokenizer = load_model_and_tokenizer('am-azadi/EXIST2024_Task2_xlmRoberta_large_3_16', 4)
best_roberta_large_model, roberta_large_model, roberta_large_tokenizer = train_model(roberta_large_model, roberta_large_tokenizer, train_df, dev_df, id2label, batch_size=16, number_of_epochs=3, learning_rates=[5e-6, 2e-6, 1e-6], weight_decay=0.07)
predicted_labels = Evaluate(best_roberta_large_model, roberta_large_tokenizer, dev_df, id2label, batch_size = 16)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/964 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.24G [00:00<?, ?B/s]
#   0%|          | 0/433 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# OutOfMemoryError                          Traceback (most recent call last)
# <ipython-input-22-ff0c6fed1d84> in <cell line: 2>()
#       1 roberta_large_model, roberta_large_tokenizer = load_model_and_tokenizer('am-azadi/EXIST2024_Task2_xlmRoberta_large_3_16', 4)
# ----> 2 best_roberta_large_model, roberta_large_model, roberta_large_tokenizer = train_model(roberta_large_model, roberta_large_tokenizer, train_df, dev_df, id2label, batch_size=16, number_of_epochs=3, learning_rates=[5e-6, 2e-6, 1e-6], weight_decay=0.07)
#       3 predicted_labels = Evaluate(best_roberta_large_model, roberta_large_tokenizer, dev_df, id2label, batch_size = 16)
#
# <ipython-input-18-1118a139672a> in train_model(model, tokenizer, train_df, val_df, id2label, batch_size, number_of_epochs, learning_rates, weight_decay)
#      58
#      59         loss.backward()
# ---> 60         optimizer.step()
#      61         scheduler.step()
#      62
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      73                 instance._step_count += 1
#      74                 wrapped = func.__get__(instance, cls)
# ---> 75                 return wrapped(*args, **kwargs)
#      76
#      77             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     383                             )
#     384
# --> 385                 out = func(*args, **kwargs)
#     386                 self._optimizer_step_code()
#     387
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      74             torch.set_grad_enabled(self.defaults['differentiable'])
#      75             torch._dynamo.graph_break()
# ---> 76             ret = func(self, *args, **kwargs)
#      77         finally:
#      78             torch._dynamo.graph_break()
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adamw.py in step(self, closure)
#     185             )
#     186
# --> 187             adamw(
#     188                 params_with_grad,
#     189                 grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adamw.py in adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     337         func = _single_tensor_adamw
#     338
# --> 339     func(
#     340         params,
#     341         grads,
#
# /usr/local/lib/python3.10/dist-packages/torch/optim/adamw.py in _multi_tensor_adamw(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, has_complex)
#     606                 exp_avg_sq_sqrt = torch._foreach_sqrt(device_max_exp_avg_sqs)
#     607             else:
# --> 608                 exp_avg_sq_sqrt = torch._foreach_sqrt(device_exp_avg_sqs)
#     609
#     610             torch._foreach_div_(exp_avg_sq_sqrt, bias_correction2_sqrt)
#
# OutOfMemoryError: CUDA out of memory. Tried to allocate 20.00 MiB. GPU 0 has a total capacity of 14.75 GiB of which 17.06 MiB is free. Process 4616 has 14.73 GiB memory in use. Of the allocated memory 14.53 GiB is allocated by PyTorch, and 25.30 MiB is reserved by PyTorch but unallocated. If reserved but unallocated memory is large try setting PYTORCH_CUDA_ALLOC_CONF=expandable_segments:True to avoid fragmentation.  See documentation for Memory Management  (https://pytorch.org/docs/stable/notes/cuda.html#environment-variables)

# %% [markdown]
# ## mbert

# %%
mBert_model, mBert_tokenizer = train_model('bert-base-multilingual-cased', train_df, dev_df, 2, id2label, False, 3, 16)
# Out:
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-multilingual-cased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 433/433 [02:45<00:00,  2.62it/s]
# 100%|██████████| 65/65 [00:08<00:00,  8.06it/s]
# Epoch 1/3
# Train loss 0.5581313246392212, accuracy 0.7031791907514451
# Dev loss 0.4620477463190372, accuracy 0.7832369942196532
# 100%|██████████| 433/433 [02:45<00:00,  2.62it/s]
# 100%|██████████| 65/65 [00:08<00:00,  8.05it/s]
# Epoch 2/3
# Train loss 0.41873579580706755, accuracy 0.8145953757225434
# Dev loss 0.4259020508481906, accuracy 0.8140655105973025
# 100%|██████████| 433/433 [02:45<00:00,  2.61it/s]
# 100%|██████████| 65/65 [00:08<00:00,  8.08it/s]
# Epoch 3/3
# Train loss 0.3016430305243915, accuracy 0.8754335260115607
# Dev loss 0.49505373457303414, accuracy 0.7967244701348748
#               precision    recall  f1-score   support
#
#           NO       0.76      0.82      0.79       479
#          YES       0.83      0.78      0.80       559
#
#     accuracy                           0.80      1038
#    macro avg       0.80      0.80      0.80      1038
# weighted avg       0.80      0.80      0.80      1038

# %% [markdown]
# # deberta model

# %%
deberta_v3_model, deberta_v3_tokenizer = train_model('microsoft/deberta-v3-base', train_df, dev_df, 2, id2label, False, 3, 16)
# Out:
# tokenizer_config.json:   0%|          | 0.00/52.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/579 [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/convert_slow_tokenizer.py:560: UserWarning: The sentencepiece tokenizer that you are converting to a fast tokenizer uses the byte fallback option which is not implemented in the fast tokenizers. In practice this means that the fast version of the tokenizer can produce unknown tokens whereas the sentencepiece version would have converted these unknown tokens into a sequence of byte tokens matching the original piece of text.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/371M [00:00<?, ?B/s]
# Some weights of DebertaV2ForSequenceClassification were not initialized from the model checkpoint at microsoft/deberta-v3-base and are newly initialized: ['classifier.bias', 'classifier.weight', 'pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 100%|██████████| 433/433 [05:39<00:00,  1.28it/s]
# 100%|██████████| 65/65 [00:10<00:00,  6.40it/s]
# Epoch 1/3
# Train loss 0.5708562995352315, accuracy 0.7010115606936416
# Dev loss 0.4414301775968992, accuracy 0.7928709055876686
# 100%|██████████| 433/433 [05:38<00:00,  1.28it/s]
# 100%|██████████| 65/65 [00:10<00:00,  6.40it/s]
# Epoch 2/3
# Train loss 0.41849323024857127, accuracy 0.8210982658959538
# Dev loss 0.44537427213329533, accuracy 0.7996146435452793
# 100%|██████████| 433/433 [05:38<00:00,  1.28it/s]
# 100%|██████████| 65/65 [00:10<00:00,  6.39it/s]
# Epoch 3/3
# Train loss 0.33082303958869697, accuracy 0.8647398843930636
# Dev loss 0.49292246636289816, accuracy 0.8111753371868978
#               precision    recall  f1-score   support
#
#           NO       0.78      0.82      0.80       479
#          YES       0.84      0.81      0.82       559
#
#     accuracy                           0.81      1038
#    macro avg       0.81      0.81      0.81      1038
# weighted avg       0.81      0.81      0.81      1038

# %%
save_and_upload(deberta_v3_model, deberta_v3_tokenizer, 'EXIST2024_Task1_deberta_v3_3_16')
# !huggingface-cli upload 'EXIST2024_Task1_deberta_v3_3_16'
# Out:
# Consider using `hf_transfer` for faster uploads. This solution comes with some limitations. See https://huggingface.co/docs/huggingface_hub/hf_transfer for more details.
# Upload 2 LFS files:   0% 0/2 [00:00<?, ?it/s]
# spm.model:   0% 0.00/2.46M [00:00<?, ?B/s]
# spm.model:   1% 16.4k/2.46M [00:00<00:18, 132kB/s]
#
# model.safetensors:   0% 0.00/738M [00:00<?, ?B/s]
#
# model.safetensors:   0% 360k/738M [00:00<03:24, 3.60MB/s]
#
# spm.model: 100% 2.46M/2.46M [00:00<00:00, 6.32MB/s]
#
#
# model.safetensors:   2% 17.4M/738M [00:00<00:21, 33.1MB/s]
#
# model.safetensors:   4% 31.6M/738M [00:00<00:11, 59.5MB/s]
#
# model.safetensors:   5% 39.4M/738M [00:00<00:18, 38.2MB/s]
#
# model.safetensors:   7% 48.0M/738M [00:01<00:20, 33.9MB/s]
#
# model.safetensors:   9% 63.0M/738M [00:01<00:13, 51.7MB/s]
#
# model.safetensors:  10% 70.8M/738M [00:01<00:15, 42.6MB/s]
#
# model.safetensors:  10% 77.0M/738M [00:01<00:16, 39.0MB/s]
#
# model.safetensors:  11% 82.2M/738M [00:02<00:26, 24.6MB/s]
#
# model.safetensors:  13% 94.5M/738M [00:02<00:17, 36.9MB/s]
#
# model.safetensors:  14% 101M/738M [00:02<00:19, 31.9MB/s]
#
# model.safetensors:  15% 109M/738M [00:02<00:16, 39.0MB/s]
#
# model.safetensors:  16% 115M/738M [00:03<00:19, 31.8MB/s]
#
# model.safetensors:  16% 121M/738M [00:03<00:16, 36.4MB/s]
#
# model.safetensors:  17% 128M/738M [00:03<00:20, 30.0MB/s]
#
# model.safetensors:  19% 139M/738M [00:03<00:14, 41.6MB/s]
#
# model.safetensors:  20% 145M/738M [00:03<00:16, 35.6MB/s]
#
# model.safetensors:  21% 157M/738M [00:04<00:11, 49.2MB/s]
#
# model.safetensors:  22% 164M/738M [00:04<00:14, 39.8MB/s]
#
# model.safetensors:  23% 170M/738M [00:04<00:17, 33.0MB/s]
#
# model.safetensors:  24% 175M/738M [00:05<00:26, 21.2MB/s]
#
# model.safetensors:  24% 178M/738M [00:05<00:32, 17.0MB/s]
#
# model.safetensors:  26% 189M/738M [00:05<00:19, 27.5MB/s]
#
# model.safetensors:  26% 194M/738M [00:05<00:21, 25.1MB/s]
#
# model.safetensors:  27% 203M/738M [00:05<00:16, 32.8MB/s]
#
# model.safetensors:  28% 208M/738M [00:06<00:18, 28.7MB/s]
#
# model.safetensors:  30% 220M/738M [00:06<00:12, 41.3MB/s]
#
# model.safetensors:  31% 226M/738M [00:06<00:15, 33.3MB/s]
#
# model.safetensors:  32% 236M/738M [00:06<00:11, 43.9MB/s]
#
# model.safetensors:  33% 242M/738M [00:07<00:14, 35.1MB/s]
#
# model.safetensors:  34% 253M/738M [00:07<00:10, 44.6MB/s]
#
# model.safetensors:  35% 259M/738M [00:07<00:12, 38.2MB/s]
#
# model.safetensors:  37% 271M/738M [00:07<00:08, 52.6MB/s]
#
# model.safetensors:  38% 278M/738M [00:07<00:12, 37.5MB/s]
#
# model.safetensors:  39% 287M/738M [00:07<00:09, 45.5MB/s]
#
# model.safetensors:  40% 294M/738M [00:08<00:21, 20.6MB/s]
#
# model.safetensors:  41% 300M/738M [00:08<00:18, 24.3MB/s]
#
# model.safetensors:  41% 305M/738M [00:09<00:19, 22.2MB/s]
#
# model.safetensors:  43% 316M/738M [00:09<00:12, 33.2MB/s]
#
# model.safetensors:  44% 322M/738M [00:09<00:16, 24.9MB/s]
#
# model.safetensors:  45% 333M/738M [00:09<00:11, 34.8MB/s]
#
# model.safetensors:  46% 339M/738M [00:10<00:13, 29.1MB/s]
#
# model.safetensors:  47% 349M/738M [00:10<00:10, 37.7MB/s]
#
# model.safetensors:  48% 355M/738M [00:10<00:12, 31.7MB/s]
#
# model.safetensors:  49% 365M/738M [00:10<00:08, 41.8MB/s]
#
# model.safetensors:  50% 371M/738M [00:10<00:10, 34.1MB/s]
#
# model.safetensors:  52% 382M/738M [00:11<00:07, 45.4MB/s]
#
# model.safetensors:  53% 388M/738M [00:11<00:11, 30.2MB/s]
#
# model.safetensors:  54% 400M/738M [00:11<00:10, 33.1MB/s]
#
# model.safetensors:  56% 410M/738M [00:11<00:07, 41.3MB/s]
#
# model.safetensors:  56% 416M/738M [00:12<00:09, 35.0MB/s]
#
# model.safetensors:  58% 427M/738M [00:12<00:06, 46.4MB/s]
#
# model.safetensors:  59% 434M/738M [00:12<00:08, 35.3MB/s]
#
# model.safetensors:  60% 442M/738M [00:12<00:07, 41.3MB/s]
#
# model.safetensors:  61% 448M/738M [00:13<00:08, 33.9MB/s]
#
# model.safetensors:  62% 459M/738M [00:13<00:06, 44.3MB/s]
#
# model.safetensors:  63% 465M/738M [00:13<00:08, 34.0MB/s]
#
# model.safetensors:  64% 474M/738M [00:13<00:06, 42.8MB/s]
#
# model.safetensors:  65% 480M/738M [00:14<00:08, 29.6MB/s]
#
# model.safetensors:  67% 494M/738M [00:14<00:05, 44.5MB/s]
#
# model.safetensors:  68% 501M/738M [00:14<00:06, 35.3MB/s]
#
# model.safetensors:  69% 509M/738M [00:14<00:05, 42.4MB/s]
#
# model.safetensors:  70% 516M/738M [00:14<00:06, 34.2MB/s]
#
# model.safetensors:  71% 526M/738M [00:14<00:04, 43.6MB/s]
#
# model.safetensors:  72% 532M/738M [00:15<00:05, 34.4MB/s]
#
# model.safetensors:  74% 544M/738M [00:15<00:04, 47.0MB/s]
#
# model.safetensors:  75% 551M/738M [00:15<00:05, 37.3MB/s]
#
# model.safetensors:  76% 560M/738M [00:15<00:04, 36.1MB/s]
#
# model.safetensors:  78% 574M/738M [00:16<00:03, 52.0MB/s]
#
# model.safetensors:  79% 582M/738M [00:16<00:04, 38.8MB/s]
#
# model.safetensors:  80% 592M/738M [00:16<00:03, 36.6MB/s]
#
# model.safetensors:  82% 606M/738M [00:16<00:02, 51.0MB/s]
#
# model.safetensors:  83% 614M/738M [00:17<00:03, 39.2MB/s]
#
# model.safetensors:  85% 624M/738M [00:17<00:03, 34.7MB/s]
#
# model.safetensors:  87% 639M/738M [00:17<00:02, 48.9MB/s]
#
# model.safetensors:  88% 647M/738M [00:17<00:02, 41.9MB/s]
#
# model.safetensors:  89% 656M/738M [00:18<00:02, 36.6MB/s]
#
# model.safetensors:  91% 671M/738M [00:18<00:01, 51.0MB/s]
#
# model.safetensors:  92% 679M/738M [00:18<00:01, 31.6MB/s]
#
# model.safetensors:  93% 688M/738M [00:19<00:01, 29.2MB/s]
#
# model.safetensors:  95% 703M/738M [00:19<00:00, 42.4MB/s]
#
# model.safetensors:  96% 711M/738M [00:20<00:00, 28.7MB/s]
#
# model.safetensors:  98% 720M/738M [00:20<00:00, 30.1MB/s]
#
# model.safetensors: 100% 738M/738M [00:20<00:00, 35.1MB/s]
# Upload 2 LFS files: 100% 2/2 [00:21<00:00, 10.72s/it]
# https://huggingface.co/am-azadi/EXIST2024_Task1_deberta_v3_3_16/tree/main/.

# %%
deberta_v3_model, deberta_v3_tokenizer = train_model('am-azadi/EXIST2024_Task1_deberta_v3_3_16', train_df, dev_df, 2, id2label, False, 2, 16)
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.28k [00:00<?, ?B/s]
# spm.model:   0%|          | 0.00/2.46M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/8.66M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/23.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/286 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/880 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/738M [00:00<?, ?B/s]
# 100%|██████████| 433/433 [05:38<00:00,  1.28it/s]
# 100%|██████████| 65/65 [00:10<00:00,  6.38it/s]
# Epoch 1/2
# Train loss 0.25462271668464287, accuracy 0.901878612716763
# Dev loss 0.47036931423040534, accuracy 0.8044315992292871
# 100%|██████████| 433/433 [05:38<00:00,  1.28it/s]
# 100%|██████████| 65/65 [00:10<00:00,  6.45it/s]
# Epoch 2/2
# Train loss 0.1887398541197353, accuracy 0.9296242774566474
# Dev loss 0.5458899609457988, accuracy 0.8140655105973025
#               precision    recall  f1-score   support
#
#           NO       0.79      0.82      0.80       479
#          YES       0.84      0.81      0.82       559
#
#     accuracy                           0.81      1038
#    macro avg       0.81      0.81      0.81      1038
# weighted avg       0.82      0.81      0.81      1038

# %% [markdown]
# # PyEvALL

# %%
# !pip install PyEvALL
# Out:
# Collecting PyEvALL
#   Downloading PyEvALL-0.1.63.tar.gz (35 kB)
#   Preparing metadata (setup.py) ... done
# Collecting jsbeautifier==1.14.9 (from PyEvALL)
#   Downloading jsbeautifier-1.14.9.tar.gz (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 3.4 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jsonschema==4.21.1 (from PyEvALL)
#   Downloading jsonschema-4.21.1-py3-none-any.whl (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.5/85.5 kB 7.2 MB/s eta 0:00:00
# Collecting numpy==1.26.4 (from PyEvALL)
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 66.3 MB/s eta 0:00:00
# Collecting pandas==2.2.1 (from PyEvALL)
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 76.9 MB/s eta 0:00:00
# Collecting setuptools==68.0.0 (from PyEvALL)
#   Downloading setuptools-68.0.0-py3-none-any.whl (804 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.0/804.0 kB 66.6 MB/s eta 0:00:00
# Requirement already satisfied: tabulate==0.9.0 in /usr/local/lib/python3.10/dist-packages (from PyEvALL) (0.9.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from jsbeautifier==1.14.9->PyEvALL) (1.16.0)
# Collecting editorconfig>=0.12.2 (from jsbeautifier==1.14.9->PyEvALL)
#   Downloading EditorConfig-0.12.4.tar.gz (13 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema==4.21.1->PyEvALL) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema==4.21.1->PyEvALL) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema==4.21.1->PyEvALL) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema==4.21.1->PyEvALL) (0.18.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.1->PyEvALL) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.1->PyEvALL) (2023.4)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas==2.2.1->PyEvALL) (2024.1)
# Building wheels for collected packages: PyEvALL, jsbeautifier, editorconfig
#   Building wheel for PyEvALL (setup.py) ... done
#   Created wheel for PyEvALL: filename=PyEvALL-0.1.63-py3-none-any.whl size=32659 sha256=7fd4e57af193cf5f3a5fcf22ae07955d58bde9391e83a2c891ffeee3db3587ad
#   Stored in directory: /root/.cache/pip/wheels/cd/3e/ac/189d7e715e0d2e46b844ac37946ebcc768d4703c7adf5c6de9
#   Building wheel for jsbeautifier (pyproject.toml) ... done
#   Created wheel for jsbeautifier: filename=jsbeautifier-1.14.9-py3-none-any.whl size=94112 sha256=6db9ddde142ae3f92a7e659235af8a0b08c59bd90f5b85420b6bf490ea6e11f4
#   Stored in directory: /root/.cache/pip/wheels/c4/5c/25/09f8b2e8dddb4fc3d70817c67b375a9069a2628847ffbdfc65
#   Building wheel for editorconfig (pyproject.toml) ... done
#   Created wheel for editorconfig: filename=EditorConfig-0.12.4-py3-none-any.whl size=16361 sha256=00ddbb270cad1dc0265f67e9057564077fdb70a82e82cb58816b4efa13d53452
#   Stored in directory: /root/.cache/pip/wheels/3a/c3/5a/39be63657db73890b21019a40a9f981b989af7d05ac7aeec8a
# Successfully built PyEvALL jsbeautifier editorconfig
# Installing collected packages: editorconfig, setuptools, numpy, jsbeautifier, pandas, jsonschema, PyEvALL
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 67.7.2
#     Uninstalling setuptools-67.7.2:
#       Successfully uninstalled setuptools-67.7.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.19.2
#     Uninstalling jsonschema-4.19.2:
#       Successfully uninstalled jsonschema-4.19.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# google-colab 1.0.0 requires pandas==2.0.3, but you have pandas 2.2.1 which is incompatible.
# Successfully installed PyEvALL-0.1.63 editorconfig-0.12.4 jsbeautifier-1.14.9 jsonschema-4.21.1 numpy-1.26.4 pandas-2.2.1 setuptools-68.0.0

# %%
from pyevall.evaluation import PyEvALLEvaluation
from pyevall.utils.utils import PyEvALLUtils

predictions = "./Data/evaluation/baselines/EXIST2024_dev_task1_majority_class_hard.json"
gold = "./Data/evaluation/golds/EXIST2024_dev_task1_gold_hard.json"
test = PyEvALLEvaluation()
params= dict()
params[PyEvALLUtils.PARAM_REPORT]= PyEvALLUtils.PARAM_OPTION_REPORT_EMBEDDED
metrics=["ICM", "ICMNorm" ,"FMeasure"]
report= test.evaluate(predictions, gold, metrics, **params)
report.print_report()
# Out:
# 2024-05-09 09:27:02,724 - pyevall.evaluation - INFO -             evaluate() - Evaluating the following metrics ['ICM', 'ICMNorm', 'FMeasure']
# 2024-05-09 09:27:03,301 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM evaluation method
# 2024-05-09 09:27:04,006 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM Normalized evaluation method
# 2024-05-09 09:27:04,011 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM evaluation method
# 2024-05-09 09:27:04,769 - pyevall.metrics.metrics - INFO -             evaluate() - Executing ICM evaluation method
# 2024-05-09 09:27:05,466 - pyevall.metrics.metrics - INFO -             evaluate() - Executing fmeasure evaluation method
# {
#   "metrics": {
#     "ICM": {
#       "name": "Information Contrast model",
#       "acronym": "ICM",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2024",
#           "average": -0.48069213773915614
#         }],
#         "average_per_test_case": -0.48069213773915614
#       }
#     },
#     "ICMNorm": {
#       "name": "Normalized Information Contrast Model",
#       "acronym": "ICM-Norm",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2024",
#           "average": 0.25953938906154145
#         }],
#         "average_per_test_case": 0.25953938906154145
#       }
#     },
#     "FMeasure": {
#       "name": "F-Measure",
#       "acronym": "F1",
#       "description": "Coming soon!",
#       "status": "OK",
#       "results": {
#         "test_cases": [{
#           "name": "EXIST2024",
#           "classes": {
#             "YES": 0,
#             "NO": 0.6315095583388266
#           },
#           "average": 0.3157547791694133
#         }],
#         "average_per_test_case": 0.3157547791694133
#       }
#     }
#   },
#   "files": {
#     "EXIST2024_dev_task1_majority_class_hard.json": {
#       "name": "EXIST2024_dev_task1_majority_class_hard.json",
#       "status": "OK",
#       "gold": false,
#       "description": "The file is correctly parser without errors or warnings.\\nFile name: EXIST2024_dev_task1_majority_class_hard.json.",
#       "errors": {}
#     },
#     "EXIST2024_dev_task1_gold_hard.json": {
#       "name": "EXIST2024_dev_task1_gold_hard.json",
#       "status": "OK",
#       "gold": true,
#       "description": "The file is correctly parser without errors or warnings.\\nFile name: EXIST2024_dev_task1_gold_hard.json.",
#       "errors": {}
#     }
#   }
# }
